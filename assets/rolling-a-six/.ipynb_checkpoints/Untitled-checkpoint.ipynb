# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
p1, p2, p3, p4 = 1/2, 1/6, 1/20, 1/100
table = f""
table +=  "|Try $$t$$|Coin Flip|6-sided Dice|20-sided Dice|1 in 100|\n"
table += f"|---------|----------------------|-------------|--------|\n"
for t in range(1, 20+1):
    pr1 = (1-p1)**(t-1) * p1
    pr2 = (1-p2)**(t-1) * p2
    pr3 = (1-p3)**(t-1) * p3
    pr4 = (1-p4)**(t-1) * p4
    table += f"|$$T = {t}$$|$${pr1 * 100 : .1f}\%$$|$${pr2 * 100 : .1f} \%$$|$${pr3 * 100 : .1f} \%$$|$${pr4 * 100 : .1f} \%$$|\n"
print(table)
# Out:
# |Try $$t$$|Coin Flip|6-sided Dice|20-sided Dice|1 in 100|
# |---------|----------------------|-------------|--------|
# |$$T = 1$$|$$ 50.0\%$$|$$ 16.7 \%$$|$$ 5.0 \%$$|$$ 1.0 \%$$|
# |$$T = 2$$|$$ 25.0\%$$|$$ 13.9 \%$$|$$ 4.8 \%$$|$$ 1.0 \%$$|
# |$$T = 3$$|$$ 12.5\%$$|$$ 11.6 \%$$|$$ 4.5 \%$$|$$ 1.0 \%$$|
# |$$T = 4$$|$$ 6.2\%$$|$$ 9.6 \%$$|$$ 4.3 \%$$|$$ 1.0 \%$$|
# |$$T = 5$$|$$ 3.1\%$$|$$ 8.0 \%$$|$$ 4.1 \%$$|$$ 1.0 \%$$|
# |$$T = 6$$|$$ 1.6\%$$|$$ 6.7 \%$$|$$ 3.9 \%$$|$$ 1.0 \%$$|
# |$$T = 7$$|$$ 0.8\%$$|$$ 5.6 \%$$|$$ 3.7 \%$$|$$ 0.9 \%$$|
# |$$T = 8$$|$$ 0.4\%$$|$$ 4.7 \%$$|$$ 3.5 \%$$|$$ 0.9 \%$$|
# |$$T = 9$$|$$ 0.2\%$$|$$ 3.9 \%$$|$$ 3.3 \%$$|$$ 0.9 \%$$|
# |$$T = 10$$|$$ 0.1\%$$|$$ 3.2 \%$$|$$ 3.2 \%$$|$$ 0.9 \%$$|
# |$$T = 11$$|$$ 0.0\%$$|$$ 2.7 \%$$|$$ 3.0 \%$$|$$ 0.9 \%$$|
# |$$T = 12$$|$$ 0.0\%$$|$$ 2.2 \%$$|$$ 2.8 \%$$|$$ 0.9 \%$$|
# |$$T = 13$$|$$ 0.0\%$$|$$ 1.9 \%$$|$$ 2.7 \%$$|$$ 0.9 \%$$|
# |$$T = 14$$|$$ 0.0\%$$|$$ 1.6 \%$$|$$ 2.6 \%$$|$$ 0.9 \%$$|
# |$$T = 15$$|$$ 0.0\%$$|$$ 1.3 \%$$|$$ 2.4 \%$$|$$ 0.9 \%$$|
# |$$T = 16$$|$$ 0.0\%$$|$$ 1.1 \%$$|$$ 2.3 \%$$|$$ 0.9 \%$$|
# |$$T = 17$$|$$ 0.0\%$$|$$ 0.9 \%$$|$$ 2.2 \%$$|$$ 0.9 \%$$|
# |$$T = 18$$|$$ 0.0\%$$|$$ 0.8 \%$$|$$ 2.1 \%$$|$$ 0.8 \%$$|
# |$$T = 19$$|$$ 0.0\%$$|$$ 0.6 \%$$|$$ 2.0 \%$$|$$ 0.8 \%$$|
# |$$T = 20$$|$$ 0.0\%$$|$$ 0.5 \%$$|$$ 1.9 \%$$|$$ 0.8 \%$$|

# %%
p1, p2, p3, p4 = 1/2, 1/6, 1/20, 1/100
table = f""
table +=  "|Try $$t$$|Coin Flip|6-sided Dice|20-sided Dice|1 in 100|\n"
table += f"|---------|----------------------|-------------|--------|\n"
cpr1, cpr2, cpr3, cpr4 = 0, 0, 0, 0
for t in range(1, 30+1):
    pr1 = (1-p1)**(t-1) * p1
    pr2 = (1-p2)**(t-1) * p2
    pr3 = (1-p3)**(t-1) * p3
    pr4 = (1-p4)**(t-1) * p4
    cpr1 += pr1
    cpr2 += pr2
    cpr3 += pr3
    cpr4 += pr4
    table += f"|$$T \le {t}$$|$${cpr1 * 100 : .1f}\%$$|$${cpr2 * 100 : .1f} \%$$|$${cpr3 * 100 : .1f} \%$$|$${cpr4 * 100 : .1f} \%$$|\n"
print(table)
# Out:
# |Try $$t$$|Coin Flip|6-sided Dice|20-sided Dice|1 in 100|
# |---------|----------------------|-------------|--------|
# |$$T \le 1$$|$$ 50.0\%$$|$$ 16.7 \%$$|$$ 5.0 \%$$|$$ 1.0 \%$$|
# |$$T \le 2$$|$$ 75.0\%$$|$$ 30.6 \%$$|$$ 9.8 \%$$|$$ 2.0 \%$$|
# |$$T \le 3$$|$$ 87.5\%$$|$$ 42.1 \%$$|$$ 14.3 \%$$|$$ 3.0 \%$$|
# |$$T \le 4$$|$$ 93.8\%$$|$$ 51.8 \%$$|$$ 18.5 \%$$|$$ 3.9 \%$$|
# |$$T \le 5$$|$$ 96.9\%$$|$$ 59.8 \%$$|$$ 22.6 \%$$|$$ 4.9 \%$$|
# |$$T \le 6$$|$$ 98.4\%$$|$$ 66.5 \%$$|$$ 26.5 \%$$|$$ 5.9 \%$$|
# |$$T \le 7$$|$$ 99.2\%$$|$$ 72.1 \%$$|$$ 30.2 \%$$|$$ 6.8 \%$$|
# |$$T \le 8$$|$$ 99.6\%$$|$$ 76.7 \%$$|$$ 33.7 \%$$|$$ 7.7 \%$$|
# |$$T \le 9$$|$$ 99.8\%$$|$$ 80.6 \%$$|$$ 37.0 \%$$|$$ 8.6 \%$$|
# |$$T \le 10$$|$$ 99.9\%$$|$$ 83.8 \%$$|$$ 40.1 \%$$|$$ 9.6 \%$$|
# |$$T \le 11$$|$$ 100.0\%$$|$$ 86.5 \%$$|$$ 43.1 \%$$|$$ 10.5 \%$$|
# |$$T \le 12$$|$$ 100.0\%$$|$$ 88.8 \%$$|$$ 46.0 \%$$|$$ 11.4 \%$$|
# |$$T \le 13$$|$$ 100.0\%$$|$$ 90.7 \%$$|$$ 48.7 \%$$|$$ 12.2 \%$$|
# |$$T \le 14$$|$$ 100.0\%$$|$$ 92.2 \%$$|$$ 51.2 \%$$|$$ 13.1 \%$$|
# |$$T \le 15$$|$$ 100.0\%$$|$$ 93.5 \%$$|$$ 53.7 \%$$|$$ 14.0 \%$$|
# |$$T \le 16$$|$$ 100.0\%$$|$$ 94.6 \%$$|$$ 56.0 \%$$|$$ 14.9 \%$$|
# |$$T \le 17$$|$$ 100.0\%$$|$$ 95.5 \%$$|$$ 58.2 \%$$|$$ 15.7 \%$$|
# |$$T \le 18$$|$$ 100.0\%$$|$$ 96.2 \%$$|$$ 60.3 \%$$|$$ 16.5 \%$$|
# |$$T \le 19$$|$$ 100.0\%$$|$$ 96.9 \%$$|$$ 62.3 \%$$|$$ 17.4 \%$$|
# |$$T \le 20$$|$$ 100.0\%$$|$$ 97.4 \%$$|$$ 64.2 \%$$|$$ 18.2 \%$$|
# |$$T \le 21$$|$$ 100.0\%$$|$$ 97.8 \%$$|$$ 65.9 \%$$|$$ 19.0 \%$$|
# |$$T \le 22$$|$$ 100.0\%$$|$$ 98.2 \%$$|$$ 67.6 \%$$|$$ 19.8 \%$$|
# |$$T \le 23$$|$$ 100.0\%$$|$$ 98.5 \%$$|$$ 69.3 \%$$|$$ 20.6 \%$$|
# |$$T \le 24$$|$$ 100.0\%$$|$$ 98.7 \%$$|$$ 70.8 \%$$|$$ 21.4 \%$$|
# |$$T \le 25$$|$$ 100.0\%$$|$$ 99.0 \%$$|$$ 72.3 \%$$|$$ 22.2 \%$$|
# |$$T \le 26$$|$$ 100.0\%$$|$$ 99.1 \%$$|$$ 73.6 \%$$|$$ 23.0 \%$$|
# |$$T \le 27$$|$$ 100.0\%$$|$$ 99.3 \%$$|$$ 75.0 \%$$|$$ 23.8 \%$$|
# |$$T \le 28$$|$$ 100.0\%$$|$$ 99.4 \%$$|$$ 76.2 \%$$|$$ 24.5 \%$$|
# |$$T \le 29$$|$$ 100.0\%$$|$$ 99.5 \%$$|$$ 77.4 \%$$|$$ 25.3 \%$$|
# |$$T \le 30$$|$$ 100.0\%$$|$$ 99.6 \%$$|$$ 78.5 \%$$|$$ 26.0 \%$$|

# %%
t = np.arange(1, 105+1)
fig, ax = plt.subplots(figsize=(20, 10))
for p in [1/2, 1/6, 1/20, 1/100]:
    pr = (1-p)**(t-1) * p
    ax.plot(t, pr, '.', label=f'p = {p*100:.0f} %', markersize=14)
ax.set_yscale('log')
ax.legend(prop={'size': 20})
ax.set_title('Probabilities')
plt.tight_layout()
fig.savefig('pr.png', transparent=True)

# %%
t = np.arange(1, 105+1)
fig, ax = plt.subplots(figsize=(20, 10))
for p in [1/2, 1/6, 1/20, 1/100]:
    pr = (1-p)**(t-1) * p
    cpr = np.cumsum(pr)
    ax.plot(t, cpr, '.', label=f'p = {p*100:.0f} %', markersize=14)
# ax.set_yscale('log')
ax.legend(prop={'size': 20})
ax.set_title('Cummulative Probabilities')
plt.tight_layout()
fig.savefig('cpr.png', transparent=True)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

t = np.arange(1, 105+1)
fig, ax = plt.subplots(figsize=(20, 10))
for i, p in enumerate([1/2, 1/6, 1/20, 1/100]):
# for i, p in enumerate([1/6]):
    et = (t * (1-p)**(t-1) * p)
    ax.plot(t, et, '.', label=f'p = {p*100:.0f} %', markersize=14)
#     ax.vlines(x=1/p, ymin=0, ymax=et[int(1/p)-1], color=colors[i])
# ax.set_yscale('log')
ax.legend(prop={'size': 20})
ax.set_title('Probabilities')
plt.tight_layout()
fig.savefig('weighted_terms.png', transparent=True)

# %%
t = np.arange(1, 3000)
table = ""
table += "|Event|Probability|$$1$$ to $$\mathbb{E}$$|$$\mathbb{E}+1$$ to $$\infty$$|$$\mathbb{E}$$|\n"
table += "|-----|-----------|-------------------------|----------------------------|--------------|\n"
events = ["Coin flip", "6-sided dice", "20-sided dice", "1 in 100"]
for i, p in enumerate([1/2, 1/6, 1/20, 1/100]):
    et = t * (1-p)**(t-1) * p
    e = int(1//p) - 1 
    table += f"|{events[i]} |$${p * 100 : .0f}\%$$|$${np.sum(et[:e+1]) : .1f}$$|$${np.sum(et[e+1:]) : .1f}$$|$${np.round(np.sum(et), 0) : .0f}$$|\n"
print(table)
# Out:
# |Event|Probability|$$1$$ to $$\mathbb{E}$$|$$\mathbb{E}+1$$ to $$\infty$$|$$\mathbb{E}$$|
# |-----|-----------|-------------------------|----------------------------|--------------|
# |Coin flip |$$ 50\%$$|$$ 1.0$$|$$ 1.0$$|$$ 2$$|
# |6-sided dice |$$ 17\%$$|$$ 2.0$$|$$ 4.0$$|$$ 6$$|
# |20-sided dice |$$ 5\%$$|$$ 5.3$$|$$ 14.7$$|$$ 20$$|
# |1 in 100 |$$ 1\%$$|$$ 26.4$$|$$ 73.6$$|$$ 100$$|

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

t = np.arange(1, 100+1)
fig, ax = plt.subplots(figsize=(20, 10))
for i, p in enumerate([1/2, 1/6, 1/20]):
    et = (t * (1-p)**(t-1) * p ) / (1/p)
    cet = np.cumsum(et)
    ax.plot(t, cet, '.', label=f'p = {p*100:.0f} %', markersize=14)
#     ax.vlines(x=1/p, ymin=0, ymax=cet[int(1/p)-1], color=colors[i])
    ax.hlines(y=1/2, xmin=0, xmax=100, color=colors[i])

# ax.set_yscale('log')
ax.legend(prop={'size': 20})
ax.set_title('Probabilities')
fig.savefig('c_weighted_terms.png', transparent=True)

# %%
# 1 - (1-p)^{\frac{1}{p}}
table = f""
table +=  "|Event|Probability $$p$$|$$\Pr(T \le \mathbb{E})$$|$$\Pr(T > \mathbb{E})$$|\n"
table += f"|-----|-----------------|-------------------------|-----------------------|\n"

ps = [1/2, 1/6, 1/20, 1/100, 1/8192, 1/13983816]
for p in ps:
    pr = 1 - (1-p)**(1/p)
    invpr = 1 - pr
    print(f"$${pr * 100 : .1f}\%$$|$${invpr * 100 : .1f}\%$$|")
# Out:
# $$ 75.0\%$$|$$ 25.0\%$$|
# $$ 66.5\%$$|$$ 33.5\%$$|
# $$ 64.2\%$$|$$ 35.8\%$$|
# $$ 63.4\%$$|$$ 36.6\%$$|
# $$ 63.2\%$$|$$ 36.8\%$$|
# $$ 63.2\%$$|$$ 36.8\%$$|
